# %% [markdown]
# # WaveNet
# WaveNet is a deep-learning based generative model for raw audio developed by Google DeepMind. The main objective of WaveNet is to generate new samples from the original distribution of data. Hence, it is known as a Generative Model.
# WaveNet is like a language model from NLP.
# The building blocks of WaveNet are convolutional layers.
#
# ## Training
# This is a many-to-one problem where the input is a sequence of amplitude values and the output is the subsequent value.
# WaveNet takes the chunk of raw audio as the input. Raw audio refers to the representation of a wave in the time series domain. In the time series domain, an audio wave is represented in the form of amplitudinal values which are recorded at different intervals of time.
#
# ## Inference
# 1. Select a random array of sample values as a starting point for the model
# 2. The model outputs a probability distribution over all the samples
# 3. Choose the value with the maximum probability and append it to the array of samples
# 4. Delete the first element and pass the array as input for the next iteration
# 5. Repeat steps 2 to 4

# %%
# imports
from music21 import *
import numpy as np
import random
import os
from collections import Counter
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from keras.layers import *
from keras.models import *
from keras.callbacks import *
import keras.backend as K

# %% [markdown]
# ## Read the midi files

# %%
# read midi file
def read_midi(file):
    print("Loading music file: ", file)

    notes = []
    notes_to_parse = None

    midi = converter.parse(file)
    
    # group based on instrument
    s2 = instrument.partitionByInstrument(midi)
    
    for part in s2.parts:
        if "Piano" not in str(part):
            continue

        notes_to_parse = part.recurse()
        
        for element in notes_to_parse:
            # note
            if isinstance(element, note.Note):
                notes.append(str(element.pitch))

            # chord
            elif isinstance(element, chord.Chord):
                notes.append('.'.join(str(n) for n in element.normalOrder))

    return np.array(notes)

# %% [markdown]
# ## Load the MIDI files

# %%
path = "./training_music/all/"
files = [i for i in os.listdir(path) if i.endswith(".mid")]
notes_array_ = [read_midi(path + i) for i in files]
typ = type(notes_array_[0])
notes_array = np.array(notes_array_, dtype=typ)
# Out:
# Loading music file:  ./training_music/all/12DaysOfChristmas.mid
# Loading music file:  ./training_music/all/2001ASpaceOddysey.mid
# Loading music file:  ./training_music/all/21Guns.mid
# Loading music file:  ./training_music/all/AddamsFamily.mid
# Loading music file:  ./training_music/all/AdventureofaLifetime(RadioEdit).mid
# Loading music file:  ./training_music/all/Africa.mid
# Loading music file:  ./training_music/all/AfterDark.mid
# Loading music file:  ./training_music/all/AllAboutThatBass.mid
# Loading music file:  ./training_music/all/AllIWantForChristmasIsYou.mid
# Loading music file:  ./training_music/all/AmericanIdiot.mid
# Loading music file:  ./training_music/all/AmericanLife.mid
# Loading music file:  ./training_music/all/AmericanPie.mid
# Loading music file:  ./training_music/all/AMessage.mid
# Loading music file:  ./training_music/all/AndILoveHer.mid
# Loading music file:  ./training_music/all/Animals.mid
# Loading music file:  ./training_music/all/AnotherBrickInTheWall.mid
# Loading music file:  ./training_music/all/AnythingButOrdinary.mid
# Loading music file:  ./training_music/all/ASkyFullofStars.mid
# Loading music file:  ./training_music/all/AThousandMiles.mid
# Loading music file:  ./training_music/all/AThousandYears.mid
# Loading music file:  ./training_music/all/AveMaria.mid
# Loading music file:  ./training_music/all/AxelF.mid
# Loading music file:  ./training_music/all/B.Y.O.B..mid
# Loading music file:  ./training_music/all/Baby.mid
# Loading music file:  ./training_music/all/BackInBlack.mid
# Loading music file:  ./training_music/all/BackToTheFuture-MainTheme.mid
# Loading music file:  ./training_music/all/Bad.mid
# Loading music file:  ./training_music/all/BadGirl.mid
# Loading music file:  ./training_music/all/BadLiar.mid
# Loading music file:  ./training_music/all/BadMoonRising.mid
# Loading music file:  ./training_music/all/BadRomance.mid
# Loading music file:  ./training_music/all/Bamboleo.mid
# Loading music file:  ./training_music/all/BeatIt.mid
# Loading music file:  ./training_music/all/BeautifulGirls.mid
# Loading music file:  ./training_music/all/BeautifulStranger.mid
# Loading music file:  ./training_music/all/BeautifulTimes.mid
# Loading music file:  ./training_music/all/BeautyAndTheBeast.mid
# Loading music file:  ./training_music/all/BecauseOfYou.mid
# Loading music file:  ./training_music/all/BestSongEver.mid
# Loading music file:  ./training_music/all/BillieJean.mid
# Loading music file:  ./training_music/all/BlackMagicWoman.mid
# Loading music file:  ./training_music/all/BlankSpace.mid
# Loading music file:  ./training_music/all/BohemianRhapsody.mid
# Loading music file:  ./training_music/all/BoulevardofBrokenDreams.mid
# Loading music file:  ./training_music/all/Breakout.mid
# Loading music file:  ./training_music/all/BringMeToLife.mid
# Loading music file:  ./training_music/all/Burn.mid
# Loading music file:  ./training_music/all/C.S.I_CriminalSceneInvestigation.mid
# Loading music file:  ./training_music/all/Californication.mid
# Loading music file:  ./training_music/all/CallMeMaybe.mid
# Loading music file:  ./training_music/all/CallTheMan.mid
# Loading music file:  ./training_music/all/CandyShop.mid
# Loading music file:  ./training_music/all/CantBeTamed.mid
# Loading music file:  ./training_music/all/CanYouFeelTheLoveTonight.mid
# Loading music file:  ./training_music/all/Celebration.mid
# Loading music file:  ./training_music/all/Chain.mid
# Loading music file:  ./training_music/all/ChasingCars.mid
# Loading music file:  ./training_music/all/Cheating.mid
# Loading music file:  ./training_music/all/Chiquitita.mid
# Loading music file:  ./training_music/all/CliffsOfDover.mid
# Loading music file:  ./training_music/all/Clocks.mid
# Loading music file:  ./training_music/all/CloseToYou.mid
# Loading music file:  ./training_music/all/Cold.mid
# Loading music file:  ./training_music/all/ColorOfMyLove.mid
# Loading music file:  ./training_music/all/Complicated.mid
# Loading music file:  ./training_music/all/ConcerningHobbits.mid
# Loading music file:  ./training_music/all/Copacabana.mid
# Loading music file:  ./training_music/all/CountingStars.mid
# Loading music file:  ./training_music/all/CountOnMe.mid
# Loading music file:  ./training_music/all/DanceIntheDark.mid
# Loading music file:  ./training_music/all/DancingQueen.mid
# Loading music file:  ./training_music/all/DarkHorse.mid
# Loading music file:  ./training_music/all/Daughters.mid
# Loading music file:  ./training_music/all/DeathAndAllHisFriends.mid
# Loading music file:  ./training_music/all/DeerInTheHeadlights.mid
# Loading music file:  ./training_music/all/DevilInHerHeart.mid
# Loading music file:  ./training_music/all/Diamonds.mid
# Loading music file:  ./training_music/all/Diana.mid
# Loading music file:  ./training_music/all/DontCha.mid
# Loading music file:  ./training_music/all/DontMatter.mid
# Loading music file:  ./training_music/all/DontPhunkWithMyHeart.mid
# Loading music file:  ./training_music/all/DontStop.mid
# Loading music file:  ./training_music/all/Dr.Who.mid
# Loading music file:  ./training_music/all/DreamsDontTurnToDust.mid
# Loading music file:  ./training_music/all/EarthSong.mid
# Loading music file:  ./training_music/all/EightDaysAWeek.mid
# Loading music file:  ./training_music/all/ElectricFeel.mid
# Loading music file:  ./training_music/all/Elvira.mid
# Loading music file:  ./training_music/all/EmpireStateofMind.mid
# Loading music file:  ./training_music/all/EnterSandman.mid
# Loading music file:  ./training_music/all/Erotica.mid
# Loading music file:  ./training_music/all/Everglow.mid
# Loading music file:  ./training_music/all/EverythingIDo.mid
# Loading music file:  ./training_music/all/EverytimeWeTouch.mid
# Loading music file:  ./training_music/all/Exorcist.mid
# Loading music file:  ./training_music/all/FamilyGuy.mid
# Loading music file:  ./training_music/all/FeelGoodInc.mid
# Loading music file:  ./training_music/all/Fever.mid
# Loading music file:  ./training_music/all/FinalCountdown.mid
# Loading music file:  ./training_music/all/FindYourLove.mid
# Loading music file:  ./training_music/all/Fireflies.mid
# Loading music file:  ./training_music/all/Firework.mid
# Loading music file:  ./training_music/all/FixYou.mid
# Loading music file:  ./training_music/all/Fly.mid
# Loading music file:  ./training_music/all/ForYouBlue.mid
# Loading music file:  ./training_music/all/FreakOut.mid
# Loading music file:  ./training_music/all/FreshPrinceOfBelAir.mid
# Loading music file:  ./training_music/all/Friends.mid
# Loading music file:  ./training_music/all/Frozen.mid
# Loading music file:  ./training_music/all/FuzzyBlueLights.mid
# Loading music file:  ./training_music/all/GangnamStyle.mid
# Loading music file:  ./training_music/all/Ghost.mid
# Loading music file:  ./training_music/all/Girlfriend.mid
# Loading music file:  ./training_music/all/GirlGoneWild.mid
# Loading music file:  ./training_music/all/GiveInToMe.mid
# Loading music file:  ./training_music/all/GivePeaceaChance.mid
# Loading music file:  ./training_music/all/GiveYourHeartABreak.mid
# Loading music file:  ./training_music/all/Gladiator.mid
# Loading music file:  ./training_music/all/God.mid
# Loading music file:  ./training_music/all/Godfather.mid
# Loading music file:  ./training_music/all/GodPutASmileUponYourFace.mid
# Loading music file:  ./training_music/all/GottaBeYou.mid
# Loading music file:  ./training_music/all/GrammyFtFuture.mid
# Loading music file:  ./training_music/all/GravityFallsOpeningThemeSong.mid
# Loading music file:  ./training_music/all/GreenEyes.mid
# Loading music file:  ./training_music/all/Grenade.mid
# Loading music file:  ./training_music/all/HailToTheChief.mid
# Loading music file:  ./training_music/all/Hallelujah.mid
# Loading music file:  ./training_music/all/HangingByAMoment.mid
# Loading music file:  ./training_music/all/Happy.mid
# Loading music file:  ./training_music/all/HappyBirthday.mid
# Loading music file:  ./training_music/all/HarryPotter.mid
# Loading music file:  ./training_music/all/Havana.mid
# Loading music file:  ./training_music/all/HealTheWorld.mid
# Loading music file:  ./training_music/all/Heartbreaker.mid
# Loading music file:  ./training_music/all/HeartbreakWarfare.mid
# Loading music file:  ./training_music/all/Heather.mid
# Loading music file:  ./training_music/all/HereComesTheSun.mid
# Loading music file:  ./training_music/all/HereWithoutYou.mid
# Loading music file:  ./training_music/all/HesaPirate.mid
# Loading music file:  ./training_music/all/HeyJude.mid
# Loading music file:  ./training_music/all/HeyThereDelilah.mid
# Loading music file:  ./training_music/all/HipsDontLie.mid
# Loading music file:  ./training_music/all/History.mid
# Loading music file:  ./training_music/all/Holiday.mid
# Loading music file:  ./training_music/all/Home.mid
# Loading music file:  ./training_music/all/Honey.mid
# Loading music file:  ./training_music/all/HoneyAndTheBee.mid
# Loading music file:  ./training_music/all/HotelCalifornia.mid
# Loading music file:  ./training_music/all/HotNCold.mid
# Loading music file:  ./training_music/all/HowDoesItFeel.mid
# Loading music file:  ./training_music/all/HowDoYouSleep.mid
# Loading music file:  ./training_music/all/HymnForTheWeekend.mid
# Loading music file:  ./training_music/all/IBelieveInYou.mid
# Loading music file:  ./training_music/all/IDroveAllNight.mid
# Loading music file:  ./training_music/all/IfIAintGotYou.mid
# Loading music file:  ./training_music/all/IfIWereABoy.mid
# Loading music file:  ./training_music/all/IGotAFeeling.mid
# Loading music file:  ./training_music/all/IKissedAGirl.mid
# Loading music file:  ./training_music/all/Imagine.mid
# Loading music file:  ./training_music/all/IMissYou.mid
# Loading music file:  ./training_music/all/ImYours.mid
# Loading music file:  ./training_music/all/InDaClub.mid
# Loading music file:  ./training_music/all/IndianaJones.mid
# Loading music file:  ./training_music/all/IntoTheGroove.mid
# Loading music file:  ./training_music/all/IReallyLikeYou.mid
# Loading music file:  ./training_music/all/IronMan.mid
# Loading music file:  ./training_music/all/Isolation.mid
# C:\Users\abhay\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\music21\midi\translate.py:863: TranslateWarning: Unable to determine instrument from <music21.midi.MidiEvent SEQUENCE_TRACK_NAME, track=14, channel=None, data=b'Copyright \xa91998'>; getting generic Instrument
#   warnings.warn(
# Loading music file:  ./training_music/all/ItsMyLife.mid
# Loading music file:  ./training_music/all/IWalkTheLine.mid
# Loading music file:  ./training_music/all/JamesBond.mid
# Loading music file:  ./training_music/all/JarOfHearts.mid
# Loading music file:  ./training_music/all/Julia.mid
# Loading music file:  ./training_music/all/JustDance.mid
# Loading music file:  ./training_music/all/JustLikeAPill.mid
# Loading music file:  ./training_music/all/JustTheWayYouAre.mid
# Loading music file:  ./training_music/all/JustTheWayyouAre.withLyric.mid
# Loading music file:  ./training_music/all/KnockingOnHeavensDoor.mid
# Loading music file:  ./training_music/all/LadyInMyLife.mid
# Loading music file:  ./training_music/all/LadyIsAVampire.mid
# Loading music file:  ./training_music/all/LetHerGo.mid
# Loading music file:  ./training_music/all/LetItGoFrozen.mid
# Loading music file:  ./training_music/all/LetMeBeTheOne.mid
# Loading music file:  ./training_music/all/LetsDance.mid
# Loading music file:  ./training_music/all/LetsGetItStarted.mid
# Loading music file:  ./training_music/all/LiberianGirl.mid
# Loading music file:  ./training_music/all/LifeOnMars.mid
# Loading music file:  ./training_music/all/Lights.mid
# Loading music file:  ./training_music/all/LilacWine.mid
# Loading music file:  ./training_music/all/LittleWonder.mid
# Loading music file:  ./training_music/all/LivinOnAPrayer.mid
# Loading music file:  ./training_music/all/LockedOutOfHeaven.mid
# Loading music file:  ./training_music/all/Lonely.mid
# Loading music file:  ./training_music/all/LordOfTheRings.mid
# Loading music file:  ./training_music/all/LoseYourself.mid
# Loading music file:  ./training_music/all/Lost.mid
# Loading music file:  ./training_music/all/LoveMeLikeYouDo.mid
# Loading music file:  ./training_music/all/LoveStory.mid
# Loading music file:  ./training_music/all/LoveTheWayYouLiePart2.mid
# Loading music file:  ./training_music/all/Maps.mid
# Loading music file:  ./training_music/all/MarryYou.mid
# Loading music file:  ./training_music/all/MarvinsRoom.mid
# Loading music file:  ./training_music/all/Matrix.mid
# Loading music file:  ./training_music/all/Mercy.mid
# Loading music file:  ./training_music/all/MissionImpossible.mid
# Loading music file:  ./training_music/all/Mother.mid
# Loading music file:  ./training_music/all/MyHeartWillGoOn.mid
# Loading music file:  ./training_music/all/MyHumps.mid
# Loading music file:  ./training_music/all/MyImmortal.mid
# Loading music file:  ./training_music/all/MyWay.mid
# Loading music file:  ./training_music/all/Natalie.mid
# Loading music file:  ./training_music/all/NeverGonnaGiveYouUp.mid
# Loading music file:  ./training_music/all/NightChanges.mid
# Loading music file:  ./training_music/all/NotFair.mid
# Loading music file:  ./training_music/all/NothingElseMatters.mid
# Loading music file:  ./training_music/all/NovemberRain.mid
# Loading music file:  ./training_music/all/NoWomanNoCry.mid
# Loading music file:  ./training_music/all/Numb.mid
# Loading music file:  ./training_music/all/OneandtheSame.mid
# Loading music file:  ./training_music/all/OneInAMillion.mid
# Loading music file:  ./training_music/all/OneStepAtATime.mid
# Loading music file:  ./training_music/all/OnlyOne.mid
# Loading music file:  ./training_music/all/OnlyOneRoad.mid
# Loading music file:  ./training_music/all/OrdinaryDay.mid
# C:\Users\abhay\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\music21\midi\translate.py:863: TranslateWarning: Unable to determine instrument from <music21.midi.MidiEvent SEQUENCE_TRACK_NAME, track=1, channel=None, data=b'\xa9 Midi-World <http://muziek.clubs.nl/midi-world>'>; getting generic Instrument
#   warnings.warn(
# Loading music file:  ./training_music/all/P.I.M.P..mid
# Loading music file:  ./training_music/all/Paradise.mid
# Loading music file:  ./training_music/all/PartyInTheUSA.mid
# Loading music file:  ./training_music/all/Payphone.mid
# Loading music file:  ./training_music/all/Perfect.mid
# Loading music file:  ./training_music/all/PianoMan.mid
# Loading music file:  ./training_music/all/PinkPanther.mid
# Loading music file:  ./training_music/all/PokerFace.mid
# Loading music file:  ./training_music/all/ReallyDontCare.mid
# Loading music file:  ./training_music/all/Ride-21pilots.mid
# Loading music file:  ./training_music/all/RightThere.mid
# Loading music file:  ./training_music/all/RingOfFire.mid
# Loading music file:  ./training_music/all/Roar.mid
# Loading music file:  ./training_music/all/Rocky.mid
# Loading music file:  ./training_music/all/Rollinginthedeep.mid
# Loading music file:  ./training_music/all/Rude.mid
# Loading music file:  ./training_music/all/RudeBoy.mid
# Loading music file:  ./training_music/all/SailAway.mid
# Loading music file:  ./training_music/all/SayItIsntSo.mid
# Loading music file:  ./training_music/all/Secrets.mid
# Loading music file:  ./training_music/all/SendMeAnAngel.mid
# Loading music file:  ./training_music/all/SetFiretotheRain.mid
# Loading music file:  ./training_music/all/SevenNationArmy.mid
# Loading music file:  ./training_music/all/ShakeItOff.mid
# Loading music file:  ./training_music/all/ShapeofYou.mid
# Loading music file:  ./training_music/all/ShowMeYourLove.mid
# Loading music file:  ./training_music/all/Simpsons.mid
# Loading music file:  ./training_music/all/SingleLadies.mid
# Loading music file:  ./training_music/all/SkaterBoy.mid
# Loading music file:  ./training_music/all/Skyscrapper.mid
# Loading music file:  ./training_music/all/Smackthat.mid
# Loading music file:  ./training_music/all/Smile.mid
# Loading music file:  ./training_music/all/Smokeonthewater(CompleteVersion).mid
# Loading music file:  ./training_music/all/SmokeOnTheWater.mid
# Loading music file:  ./training_music/all/SmoothCriminal.mid
# Loading music file:  ./training_music/all/SomeoneLikeYou.mid
# Loading music file:  ./training_music/all/Someonelikeyouwitlyric.mid
# Loading music file:  ./training_music/all/SomeonesWatchingOverMe.mid
# Loading music file:  ./training_music/all/SomethingForThePain.mid
# Loading music file:  ./training_music/all/SomethingKindaFunny.mid
# Loading music file:  ./training_music/all/SomewhereInBetween.mid
# Loading music file:  ./training_music/all/SoThisisChristmas.mid
# C:\Users\abhay\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\music21\midi\translate.py:863: TranslateWarning: Unable to determine instrument from <music21.midi.MidiEvent SEQUENCE_TRACK_NAME, track=0, channel=None, data=b'So This Is Xmas\xff\xff Popular Song\r'>; getting generic Instrument
#   warnings.warn(
# Loading music file:  ./training_music/all/SoWhat.mid
# Loading music file:  ./training_music/all/SoYesterday.mid
# Loading music file:  ./training_music/all/Spin.mid
# Loading music file:  ./training_music/all/SpongBobSquarPantsTheme.mid
# Loading music file:  ./training_music/all/StandByMe.mid
# Loading music file:  ./training_music/all/StayWithMe.mid
# Loading music file:  ./training_music/all/StepByStep.mid
# Loading music file:  ./training_music/all/StillGotTheBlues.mid
# Loading music file:  ./training_music/all/StingInTheTail.mid
# Loading music file:  ./training_music/all/StoryOfMyLife.mid
# Loading music file:  ./training_music/all/Sugar.mid
# Loading music file:  ./training_music/all/SultansOfSwing.mid
# Loading music file:  ./training_music/all/Superman.mid
# Loading music file:  ./training_music/all/SuperMarioBrothers.mid
# Loading music file:  ./training_music/all/Sway.mid
# Loading music file:  ./training_music/all/SweetChildOfMine.mid
# Loading music file:  ./training_music/all/SweetestGoodbye.mid
# Loading music file:  ./training_music/all/SweetHomeAlabama.mid
# Loading music file:  ./training_music/all/TeardropsOnMyGuitar.mid
# Loading music file:  ./training_music/all/TearsInHeaven.mid
# Loading music file:  ./training_music/all/Telephone.mid
# Loading music file:  ./training_music/all/TellMeSomethingIDontKnow.mid
# Loading music file:  ./training_music/all/TheClimb.mid
# Loading music file:  ./training_music/all/TheEndOfTheWorld.mid
# Loading music file:  ./training_music/all/TheHobbit-MistyMountainCold.mid
# Loading music file:  ./training_music/all/Thelazysong.mid
# Loading music file:  ./training_music/all/Theme.mid
# Loading music file:  ./training_music/all/ThemeA.mid
# Loading music file:  ./training_music/all/ThemeB.mid
# Loading music file:  ./training_music/all/TheRainbowConnection.mid
# Loading music file:  ./training_music/all/TheScientist.mid
# Loading music file:  ./training_music/all/TheyDontKnowAboutUs(pianoversion).mid
# Loading music file:  ./training_music/all/ThingsIllNeverSay.mid
# Loading music file:  ./training_music/all/ThinkingOutLoud.mid
# Loading music file:  ./training_music/all/ThisKiss.mid
# Loading music file:  ./training_music/all/ThisLove.mid
# Loading music file:  ./training_music/all/Thriller.mid
# Loading music file:  ./training_music/all/TimeInABottle.mid
# Loading music file:  ./training_music/all/TimeIsRunningOut.mid
# Loading music file:  ./training_music/all/Titantic.mid
# Loading music file:  ./training_music/all/Treasure.mid
# Loading music file:  ./training_music/all/Trouble.mid
# Loading music file:  ./training_music/all/UEFA-ChampionsLeague.mid
# Loading music file:  ./training_music/all/Umbrella.mid
# Loading music file:  ./training_music/all/Unfaithful.mid
# Loading music file:  ./training_music/all/UnitedStates.mid
# Loading music file:  ./training_music/all/UpAllNight.mid
# Loading music file:  ./training_music/all/VanillaTwilight.mid
# Loading music file:  ./training_music/all/VisionOfLove.mid
# Loading music file:  ./training_music/all/VivalaVida(2).mid
# Loading music file:  ./training_music/all/WakaWaka.mid
# Loading music file:  ./training_music/all/WalkThisWay.mid
# Loading music file:  ./training_music/all/Wannabe.mid
# Loading music file:  ./training_music/all/Wanttowantme.mid
# Loading music file:  ./training_music/all/WaterFromTheMoon.mid
# Loading music file:  ./training_music/all/WeWillRockYou.mid
# Loading music file:  ./training_music/all/WhateverGetsYouThruTheNight.mid
# Loading music file:  ./training_music/all/WhatMakesYouBeautiful.mid
# Loading music file:  ./training_music/all/WhenIFallInLove.mid
# Loading music file:  ./training_music/all/WhenYoureGone.mid
# Loading music file:  ./training_music/all/WhereDoesMyHeartBeatNow.mid
# Loading music file:  ./training_music/all/WhereHaveYouBeen(ExtendRemix)-Feat.CalvinHarris.mid
# Loading music file:  ./training_music/all/WhereIsTheLove.mid
# Loading music file:  ./training_music/all/WhiteShadows.mid
# Loading music file:  ./training_music/all/WindOfChange.mid
# Loading music file:  ./training_music/all/WishYouWereHere.mid
# Loading music file:  ./training_music/all/WonderfulTonight.mid
# Loading music file:  ./training_music/all/WorkingClassHero.mid
# Loading music file:  ./training_music/all/WreckingBall.mid
# Loading music file:  ./training_music/all/Yesterday.mid
# Loading music file:  ./training_music/all/YMCA.mid
# Loading music file:  ./training_music/all/YouBelongWithMe.mid
# Loading music file:  ./training_music/all/YoullAlwaysFindYourWayBackHome.mid
# Loading music file:  ./training_music/all/YouMakeMeWanna.mid
# Loading music file:  ./training_music/all/YoungGirls.mid
# Loading music file:  ./training_music/all/YouRaiseMeUp.mid
# Loading music file:  ./training_music/all/YourBodyIsAWonderland.mid
# Loading music file:  ./training_music/all/YoureBeautiful.mid

# %% [markdown]
# ### Understand the data

# %%
notes_ = [element for note_ in notes_array for element in note_]
unique_notes = list(set(notes_))
print(len(unique_notes))
# Out:
# 862

# %% [markdown]
# ### Frequency distribution and filtering out rarely occuring notes

# %%
# understand the frequency distribution
freq = dict(Counter(notes_))
no = [count for _, count in freq.items()]
plt.hist(no)
plt.ylabel("Number of notes")
plt.xlabel("Frequency of occurence")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 2
#       1 # understand the frequency distribution
# ----> 2 freq = dict(Counter(notes_))
#       3 no = [count for _, count in freq.items()]
#       4 plt.hist(no)
#
# NameError: name 'Counter' is not defined

# %%
# filter
FREQ_THRESHOLD = 40
freq_notes = [note_ for note_, count in freq.items() if count >= FREQ_THRESHOLD]
print(len(freq_notes))
# Out:
# 188

# %% [markdown]
# ### Prepare input (sequence of notes) - output pairs (successive note) for the model

# %%
new_music = []

for notes in notes_array:
    temp = []
    for note_ in notes:
        if note_ in freq_notes:
            temp.append(note_)
    new_music.append(temp)
new_music = np.array(new_music, dtype=type(new_music[0]))

# %%
num_timesteps = 32
x = []
y = []

for note_ in new_music:
    for i in range(0, len(note_) - num_timesteps):
        input_ = note_[i:i + num_timesteps]
        output_ = note_[i + num_timesteps]

        x.append(input_)
        y.append(output_)

x = np.array(x)
y = np.array(y)

# %% [markdown]
# ### Convert the notes via one to one mapping - The model works on numbers only

# %%
# assign a unique integer for every note
unique_x = list(set(x.ravel()))
x_note_to_int = dict((note_, number) for number, note_ in enumerate(unique_x))

# %%
# convert notes to numbers
x_seq = []
for i in x:
    temp = []

    for j in i:
        temp.append(x_note_to_int[j])

    x_seq.append(temp)
x_seq = np.array(x_seq)

# %%
unique_y = list(set(y))
y_note_to_int = dict((note_, number) for number, note_ in enumerate(unique_y))
y_seq = np.array([y_note_to_int[i] for i in y])

# %% [markdown]
# ### Train Test Split

# %%
x_train, x_val, y_train, y_val = train_test_split(x_seq, y_seq, test_size=0.2, random_state=0)

# %% [markdown]
# ## Model Building

# %%
K.clear_session()
model = Sequential()
    
#embedding layer
model.add(Embedding(len(unique_x), 100, input_length=32,trainable=True)) 

model.add(Conv1D(64,3, padding='causal',activation='relu'))
model.add(Dropout(0.2))
model.add(MaxPool1D(2))
    
model.add(Conv1D(128,3,activation='relu',dilation_rate=2,padding='causal'))
model.add(Dropout(0.2))
model.add(MaxPool1D(2))

model.add(Conv1D(256,3,activation='relu',dilation_rate=4,padding='causal'))
model.add(Dropout(0.2))
model.add(MaxPool1D(2))
          
#model.add(Conv1D(256,5,activation='relu'))    
model.add(GlobalMaxPool1D())
    
model.add(Dense(256, activation='relu'))
model.add(Dense(len(unique_y), activation='softmax'))
    
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam')

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 32, 100)           18800
#
#  conv1d (Conv1D)             (None, 32, 64)            19264
#
#  dropout (Dropout)           (None, 32, 64)            0
#
#  max_pooling1d (MaxPooling1D  (None, 16, 64)           0
#  )
#
#  conv1d_1 (Conv1D)           (None, 16, 128)           24704
#
#  dropout_1 (Dropout)         (None, 16, 128)           0
#
#  max_pooling1d_1 (MaxPooling  (None, 8, 128)           0
#  1D)
#
#  conv1d_2 (Conv1D)           (None, 8, 256)            98560
#
#  dropout_2 (Dropout)         (None, 8, 256)            0
#
#  max_pooling1d_2 (MaxPooling  (None, 4, 256)           0
#  1D)
#
#  global_max_pooling1d (Globa  (None, 256)              0
#  lMaxPooling1D)
#
#  dense (Dense)               (None, 256)               65792
#
#  dense_1 (Dense)             (None, 188)               48316
#
# =================================================================
# Total params: 275,436
# Trainable params: 275,436
# Non-trainable params: 0
# _________________________________________________________________

# %%
mc = ModelCheckpoint("best_model.h5", monitor="val_loss", mode="min", save_best_only=True, verbose=1)

# %%
history = model.fit(np.array(x_train), np.array(y_train), batch_size=256, epochs=50, validation_data=(np.array(x_val), np.array(y_val)), verbose=1, callbacks=[mc])
# Out:
# Epoch 1/50
# 284/285 [============================>.] - ETA: 0s - loss: 1.7777
# Epoch 1: val_loss did not improve from 2.08269
# 285/285 [==============================] - 20s 68ms/step - loss: 1.7780 - val_loss: 2.1523
# Epoch 2/50
# 284/285 [============================>.] - ETA: 0s - loss: 1.7993
# Epoch 2: val_loss did not improve from 2.08269
# 285/285 [==============================] - 22s 76ms/step - loss: 1.7996 - val_loss: 2.1536
# Epoch 3/50
# 284/285 [============================>.] - ETA: 0s - loss: 1.7957
# Epoch 3: val_loss did not improve from 2.08269
# 285/285 [==============================] - 21s 75ms/step - loss: 1.7960 - val_loss: 2.1543
# Epoch 4/50
# 284/285 [============================>.] - ETA: 0s - loss: 1.7925
# Epoch 4: val_loss did not improve from 2.08269
# 285/285 [==============================] - 21s 74ms/step - loss: 1.7925 - val_loss: 2.1525
# Epoch 5/50
# 284/285 [============================>.] - ETA: 0s - loss: 1.7905
# Epoch 5: val_loss did not improve from 2.08269
# 285/285 [==============================] - 21s 73ms/step - loss: 1.7904 - val_loss: 2.1437
# Epoch 6/50
# 284/285 [============================>.] - ETA: 0s - loss: 1.7899
# Epoch 6: val_loss did not improve from 2.08269
# 285/285 [==============================] - 21s 74ms/step - loss: 1.7903 - val_loss: 2.1453
# Epoch 7/50
# 284/285 [============================>.] - ETA: 0s - loss: 1.7838
# Epoch 7: val_loss did not improve from 2.08269
# 285/285 [==============================] - 21s 72ms/step - loss: 1.7841 - val_loss: 2.1413
# Epoch 8/50
# 284/285 [============================>.] - ETA: 0s - loss: 1.7837
# Epoch 8: val_loss did not improve from 2.08269
# 285/285 [==============================] - 22s 76ms/step - loss: 1.7838 - val_loss: 2.1443
# Epoch 9/50
# 284/285 [============================>.] - ETA: 0s - loss: 1.7750
# Epoch 9: val_loss did not improve from 2.08269
# 285/285 [==============================] - 22s 76ms/step - loss: 1.7756 - val_loss: 2.1390
# Epoch 10/50
# 284/285 [============================>.] - ETA: 0s - loss: 1.7800
# Epoch 10: val_loss did not improve from 2.08269
# 285/285 [==============================] - 22s 79ms/step - loss: 1.7801 - val_loss: 2.1404
# Epoch 11/50
# 284/285 [============================>.] - ETA: 0s - loss: 1.7689
# Epoch 11: val_loss did not improve from 2.08269
# 285/285 [==============================] - 21s 75ms/step - loss: 1.7690 - val_loss: 2.1374
# Epoch 12/50
# 284/285 [============================>.] - ETA: 0s - loss: 1.7698
# Epoch 12: val_loss did not improve from 2.08269
# 285/285 [==============================] - 21s 73ms/step - loss: 1.7698 - val_loss: 2.1390
# Epoch 13/50
# 284/285 [============================>.] - ETA: 0s - loss: 1.7691
# Epoch 13: val_loss did not improve from 2.08269
# 285/285 [==============================] - 19s 68ms/step - loss: 1.7690 - val_loss: 2.1354
# Epoch 14/50
# 284/285 [============================>.] - ETA: 0s - loss: 1.7671
# Epoch 14: val_loss did not improve from 2.08269
# 285/285 [==============================] - 19s 66ms/step - loss: 1.7671 - val_loss: 2.1266
# Epoch 15/50
# 284/285 [============================>.] - ETA: 0s - loss: 1.7692
# Epoch 15: val_loss did not improve from 2.08269
# 285/285 [==============================] - 19s 66ms/step - loss: 1.7688 - val_loss: 2.1319
# Epoch 16/50
# 284/285 [============================>.] - ETA: 0s - loss: 1.7605
# Epoch 16: val_loss did not improve from 2.08269
# 285/285 [==============================] - 19s 66ms/step - loss: 1.7606 - val_loss: 2.1331
# Epoch 17/50
# 284/285 [============================>.] - ETA: 0s - loss: 1.7521
# Epoch 17: val_loss did not improve from 2.08269
# 285/285 [==============================] - 19s 66ms/step - loss: 1.7519 - val_loss: 2.1323
# Epoch 18/50
# 284/285 [============================>.] - ETA: 0s - loss: 1.7616
# Epoch 18: val_loss did not improve from 2.08269
# 285/285 [==============================] - 19s 66ms/step - loss: 1.7617 - val_loss: 2.1258
# Epoch 19/50
# 284/285 [============================>.] - ETA: 0s - loss: 1.7565
# Epoch 19: val_loss did not improve from 2.08269
# 285/285 [==============================] - 19s 65ms/step - loss: 1.7565 - val_loss: 2.1239
# Epoch 20/50
# 284/285 [============================>.] - ETA: 0s - loss: 1.7579
# Epoch 20: val_loss did not improve from 2.08269
# 285/285 [==============================] - 19s 65ms/step - loss: 1.7574 - val_loss: 2.1264
# Epoch 21/50
# 284/285 [============================>.] - ETA: 0s - loss: 1.7535
# Epoch 21: val_loss did not improve from 2.08269
# 285/285 [==============================] - 19s 67ms/step - loss: 1.7533 - val_loss: 2.1232
# Epoch 22/50
# 284/285 [============================>.] - ETA: 0s - loss: 1.7438
# Epoch 22: val_loss did not improve from 2.08269
# 285/285 [==============================] - 19s 66ms/step - loss: 1.7437 - val_loss: 2.1184
# Epoch 23/50
# 284/285 [============================>.] - ETA: 0s - loss: 1.7471
# Epoch 23: val_loss did not improve from 2.08269
# 285/285 [==============================] - 19s 66ms/step - loss: 1.7473 - val_loss: 2.1246
# Epoch 24/50
# 284/285 [============================>.] - ETA: 0s - loss: 1.7421
# Epoch 24: val_loss did not improve from 2.08269
# 285/285 [==============================] - 19s 66ms/step - loss: 1.7425 - val_loss: 2.1267
# Epoch 25/50
# 284/285 [============================>.] - ETA: 0s - loss: 1.7385
# Epoch 25: val_loss did not improve from 2.08269
# 285/285 [==============================] - 19s 68ms/step - loss: 1.7381 - val_loss: 2.1233
# Epoch 26/50
# 284/285 [============================>.] - ETA: 0s - loss: 1.7423
# Epoch 26: val_loss did not improve from 2.08269
# 285/285 [==============================] - 20s 71ms/step - loss: 1.7424 - val_loss: 2.1284
# Epoch 27/50
# 284/285 [============================>.] - ETA: 0s - loss: 1.7439
# Epoch 27: val_loss did not improve from 2.08269
# 285/285 [==============================] - 20s 70ms/step - loss: 1.7439 - val_loss: 2.1300
# Epoch 28/50
# 284/285 [============================>.] - ETA: 0s - loss: 1.7409
# Epoch 28: val_loss did not improve from 2.08269
# 285/285 [==============================] - 20s 69ms/step - loss: 1.7409 - val_loss: 2.1333
# Epoch 29/50
# 284/285 [============================>.] - ETA: 0s - loss: 1.7416
# Epoch 29: val_loss did not improve from 2.08269
# 285/285 [==============================] - 20s 70ms/step - loss: 1.7416 - val_loss: 2.1253
# Epoch 30/50
# 284/285 [============================>.] - ETA: 0s - loss: 1.7340
# Epoch 30: val_loss did not improve from 2.08269
# 285/285 [==============================] - 19s 67ms/step - loss: 1.7336 - val_loss: 2.1181
# Epoch 31/50
# 284/285 [============================>.] - ETA: 0s - loss: 1.7375
# Epoch 31: val_loss did not improve from 2.08269
# 285/285 [==============================] - 21s 72ms/step - loss: 1.7377 - val_loss: 2.1193
# Epoch 32/50
# 284/285 [============================>.] - ETA: 0s - loss: 1.7400
# Epoch 32: val_loss did not improve from 2.08269
# 285/285 [==============================] - 19s 67ms/step - loss: 1.7399 - val_loss: 2.1113
# Epoch 33/50
# 284/285 [============================>.] - ETA: 0s - loss: 1.7277
# Epoch 33: val_loss did not improve from 2.08269
# 285/285 [==============================] - 19s 66ms/step - loss: 1.7277 - val_loss: 2.1160
# Epoch 34/50
# 284/285 [============================>.] - ETA: 0s - loss: 1.7257
# Epoch 34: val_loss did not improve from 2.08269
# 285/285 [==============================] - 19s 66ms/step - loss: 1.7261 - val_loss: 2.1240
# Epoch 35/50
# 284/285 [============================>.] - ETA: 0s - loss: 1.7330
# Epoch 35: val_loss did not improve from 2.08269
# 285/285 [==============================] - 19s 66ms/step - loss: 1.7327 - val_loss: 2.1213
# Epoch 36/50
# 284/285 [============================>.] - ETA: 0s - loss: 1.7328
# Epoch 36: val_loss did not improve from 2.08269
# 285/285 [==============================] - 19s 66ms/step - loss: 1.7327 - val_loss: 2.1078
# Epoch 37/50
# 284/285 [============================>.] - ETA: 0s - loss: 1.7234
# Epoch 37: val_loss did not improve from 2.08269
# 285/285 [==============================] - 19s 66ms/step - loss: 1.7234 - val_loss: 2.1202
# Epoch 38/50
# 284/285 [============================>.] - ETA: 0s - loss: 1.7258
# Epoch 38: val_loss did not improve from 2.08269
# 285/285 [==============================] - 19s 66ms/step - loss: 1.7256 - val_loss: 2.1074
# Epoch 39/50
# 284/285 [============================>.] - ETA: 0s - loss: 1.7195
# Epoch 39: val_loss did not improve from 2.08269
# 285/285 [==============================] - 19s 66ms/step - loss: 1.7199 - val_loss: 2.1063
# Epoch 40/50
# 284/285 [============================>.] - ETA: 0s - loss: 1.7255
# Epoch 40: val_loss did not improve from 2.08269
# 285/285 [==============================] - 19s 66ms/step - loss: 1.7253 - val_loss: 2.1114
# Epoch 41/50
# 284/285 [============================>.] - ETA: 0s - loss: 1.7148
# Epoch 41: val_loss did not improve from 2.08269
# 285/285 [==============================] - 19s 66ms/step - loss: 1.7145 - val_loss: 2.1108
# Epoch 42/50
# 284/285 [============================>.] - ETA: 0s - loss: 1.7127
# Epoch 42: val_loss did not improve from 2.08269
# 285/285 [==============================] - 19s 66ms/step - loss: 1.7131 - val_loss: 2.1104
# Epoch 43/50
# 284/285 [============================>.] - ETA: 0s - loss: 1.7185
# Epoch 43: val_loss did not improve from 2.08269
# 285/285 [==============================] - 19s 66ms/step - loss: 1.7187 - val_loss: 2.1117
# Epoch 44/50
# 284/285 [============================>.] - ETA: 0s - loss: 1.7079
# Epoch 44: val_loss did not improve from 2.08269
# 285/285 [==============================] - 19s 66ms/step - loss: 1.7081 - val_loss: 2.1116
# Epoch 45/50
# 284/285 [============================>.] - ETA: 0s - loss: 1.7128
# Epoch 45: val_loss did not improve from 2.08269
# 285/285 [==============================] - 19s 66ms/step - loss: 1.7127 - val_loss: 2.1091
# Epoch 46/50
# 284/285 [============================>.] - ETA: 0s - loss: 1.7125
# Epoch 46: val_loss did not improve from 2.08269
# 285/285 [==============================] - 20s 72ms/step - loss: 1.7126 - val_loss: 2.1167
# Epoch 47/50
# 284/285 [============================>.] - ETA: 0s - loss: 1.7189
# Epoch 47: val_loss did not improve from 2.08269
# 285/285 [==============================] - 20s 70ms/step - loss: 1.7192 - val_loss: 2.1089
# Epoch 48/50
# 284/285 [============================>.] - ETA: 0s - loss: 1.7075
# Epoch 48: val_loss did not improve from 2.08269
# 285/285 [==============================] - 19s 66ms/step - loss: 1.7074 - val_loss: 2.1082
# Epoch 49/50
# 284/285 [============================>.] - ETA: 0s - loss: 1.7129
# Epoch 49: val_loss did not improve from 2.08269
# 285/285 [==============================] - 19s 66ms/step - loss: 1.7129 - val_loss: 2.1092
# Epoch 50/50
# 284/285 [============================>.] - ETA: 0s - loss: 1.7055
# Epoch 50: val_loss did not improve from 2.08269
# 285/285 [==============================] - 19s 65ms/step - loss: 1.7054 - val_loss: 2.1130

# %%
# load the best model
model = load_model("best_model.h5")

# %% [markdown]
# ## Compose our own music

# %%
random_index = np.random.randint(0, len(x_val) - 1)
random_music = x_val[random_index]
predictions = []

for i in range(100):
    random_music = random_music.reshape(1, num_timesteps)
    prob = model.predict(random_music)[0]
    y_pred = np.argmax(prob, axis=0)
    predictions.append(y_pred)

    random_music = np.insert(random_music[0], len(random_music[0]), y_pred)
    random_music = random_music[1:]

predictions
# Out:
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# [6,
#  6,
#  90,
#  6,
#  90,
#  6,
#  6,
#  6,
#  4,
#  90,
#  183,
#  90,
#  183,
#  183,
#  183,
#  96,
#  183,
#  20,
#  20,
#  168,
#  183,
#  183,
#  183,
#  183,
#  183,
#  177,
#  183,
#  183,
#  20,
#  183,
#  71,
#  183,
#  183,
#  183,
#  183,
#  106,
#  183,
#  183,
#  183,
#  183,
#  183,
#  183,
#  183,
#  183,
#  183,
#  183,
#  183,
#  183,
#  183,
#  183,
#  106,
#  183,
#  183,
#  106,
#  106,
#  134,
#  183,
#  134,
#  96,
#  96,
#  96,
#  96,
#  96,
#  96,
#  96,
#  96,
#  96,
#  96,
#  96,
#  96,
#  96,
#  96,
#  96,
#  96,
#  96,
#  96,
#  96,
#  96,
#  96,
#  96,
#  96,
#  96,
#  96,
#  96,
#  96,
#  96,
#  96,
#  96,
#  96,
#  96,
#  96,
#  96,
#  96,
#  96,
#  96,
#  96,
#  96,
#  96,
#  96,
#  96]

# %%
# intergers to notes
x_int_to_note = dict((number, note_) for number, note_ in enumerate(unique_x))
predicted_notes = [x_int_to_note[n] for n in predictions]

# %%
def to_midi(prediction):
    offset = 0
    output_notes = []

    for pattern in prediction:
        # chord
        if '.' in pattern or pattern.isdigit():
            notes_in_chord = pattern.split('.')
            notes = []

            for current_note in notes_in_chord:
                cn = int(current_note)

                new_note = note.Note(cn)
                new_note.storedInstrument = instrument.Piano()
                notes.append(new_note)

            new_chord = chord.Chord(notes)
            new_chord.offset = offset
            output_notes.append(new_chord)
        
        # note
        else:
            new_note = note.Note(pattern)
            new_note.offset = offset
            new_note.storedInstrument = instrument.Piano()
            output_notes.append(new_note)

        offset += 1

    midi_stream = stream.Stream(output_notes)
    midi_stream.write("midi", fp="gen_music.mid")

# %%
to_midi(predicted_notes)

# %%
predicted_notes
# Out:
# ['B3',
#  'B3',
#  'G2',
#  'B3',
#  'G2',
#  'B3',
#  'B3',
#  'B3',
#  'C3',
#  'G2',
#  'F2',
#  'G2',
#  'F2',
#  'F2',
#  'F2',
#  '0.5',
#  'F2',
#  'F3',
#  'F3',
#  '5.9',
#  'F2',
#  'F2',
#  'F2',
#  'F2',
#  'F2',
#  '5.9.0',
#  'F2',
#  'F2',
#  'F3',
#  'F2',
#  'F4',
#  'F2',
#  'F2',
#  'F2',
#  'F2',
#  'C5',
#  'F2',
#  'F2',
#  'F2',
#  'F2',
#  'F2',
#  'F2',
#  'F2',
#  'F2',
#  'F2',
#  'F2',
#  'F2',
#  'F2',
#  'F2',
#  'F2',
#  'C5',
#  'F2',
#  'F2',
#  'C5',
#  'C5',
#  'B-4',
#  'F2',
#  'B-4',
#  '0.5',
#  '0.5',
#  '0.5',
#  '0.5',
#  '0.5',
#  '0.5',
#  '0.5',
#  '0.5',
#  '0.5',
#  '0.5',
#  '0.5',
#  '0.5',
#  '0.5',
#  '0.5',
#  '0.5',
#  '0.5',
#  '0.5',
#  '0.5',
#  '0.5',
#  '0.5',
#  '0.5',
#  '0.5',
#  '0.5',
#  '0.5',
#  '0.5',
#  '0.5',
#  '0.5',
#  '0.5',
#  '0.5',
#  '0.5',
#  '0.5',
#  '0.5',
#  '0.5',
#  '0.5',
#  '0.5',
#  '0.5',
#  '0.5',
#  '0.5',
#  '0.5',
#  '0.5',
#  '0.5',
#  '0.5']
